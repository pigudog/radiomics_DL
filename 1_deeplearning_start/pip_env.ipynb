# %%
pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      1.4.0
# aiobotocore                  2.5.4
# aiohttp                      3.8.5
# aioitertools                 0.11.0
# aiosignal                    1.3.1
# anndata                      0.9.2
# annotated-types              0.5.0
# annoy                        1.17.0
# ansicon                      1.89.0
# anyio                        3.7.1
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asciitree                    0.3.3
# asttokens                    2.4.0
# astunparse                   1.6.3
# async-lru                    2.0.4
# async-timeout                4.0.3
# attrs                        23.1.0
# Babel                        2.14.0
# backcall                     0.2.0
# backoff                      2.2.1
# beautifulsoup4               4.12.2
# bleach                       6.1.0
# ...
